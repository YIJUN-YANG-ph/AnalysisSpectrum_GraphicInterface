# %%
# using latex

# %% [markdown]
# # Heterodyne mesurement of Q factor

# %% [markdown]
# $$I(t) = A_1^2 + A_2^2 + 2A_1 A_2 \cos (\Delta \omega t)$$
# $$I(t)_{SA} \propto A_1 A_2 \cos (\Delta \omega t)$$

# %% [markdown]
# The power measured from spectrum anayalser
# $$P_{electric} \propto I^2$$

# %% [markdown]
# $$P_{electric} \propto I^2 \propto A_2^2 \propto T_{optical}$$
